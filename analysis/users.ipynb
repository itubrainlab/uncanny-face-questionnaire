# %%
import pandas as pd
import glob

# %%
user_files = glob.glob("../export/*_user.csv")
user_files.sort()
user_files[-1]
# Out:
# '../export/20230104-175319_user.csv'

# %%
users = pd.read_csv(user_files[-1], index_col=["index"],
                    names=["index", "id", "uid", "age", "gender", "language", "timestamp"])

# %% [markdown]
# # Age Distribution

# %%
users["age"].hist()
users["age"].describe()
# Out:
# count    273.000000
# mean      29.615385
# std        8.262828
# min       17.000000
# 25%       23.000000
# 50%       28.000000
# 75%       35.000000
# max       57.000000
# Name: age, dtype: float64

# %% [markdown]
# # Gender Distribution

# %%
users["gender"].map({0: "None", 1: "Female", 2: "Male", 3: "Other"}).hist()
users["gender"].map({0: "None", 1: "Female", 2: "Male", 3: "Other"}).describe()
# Out:
# count      274
# unique       4
# top       Male
# freq       169
# Name: gender, dtype: object

# %% [markdown]
# # Lnguage Distribution

# %%
users["language"].map({0: "None", 1: "English", 2: "Non-english"}).hist(bins=3)
users["language"].map({0: "None", 1: "English", 2: "Non-english"}).describe()
# Out:
# count             274
# unique              2
# top       Non-english
# freq              153
# Name: language, dtype: object
